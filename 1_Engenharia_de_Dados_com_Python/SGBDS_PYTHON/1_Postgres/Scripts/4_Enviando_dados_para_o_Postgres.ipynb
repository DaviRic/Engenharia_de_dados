# %% [markdown]
# Passos do projeto:
# 1°: importar json como DF;
#
# 2°: Tratar os dados. Levar em considaração apenas as colunas: ["Numero da ocorrencia", "Classificacao da ocorrencia", "Data da ocorrencia", "Municipio", "UF", "Regiao"];
#
# 3°: Tirar o acento dos nomes das colunas;
#
# 4°: Criar banco de dados e tabela;
#
# 5°: Configurar a conexão;
#
# 6°: Enviar dados para o Postgre;
#
# 7°: Criar um DELETE da tabela para não ver histórico, mantendo em banco sempre os dados mais recentes;
#
# 8°: Refatorar código (apagar o que não vai ser usado);
#
# 9°:

# %% [markdown]
# #### 1°: Importar json como DF

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
caminho_do_arquivo = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Postgree\V_OCORRENCIA_AMPLA.json"
df = pd.read_json(caminho_do_arquivo, encoding='utf-8')
df.head()
# Out:
#    Numero_da_Ocorrencia Numero_da_Ficha                Operador_Padronizado  \
# 0                 25626       202096550  MINIST.JUST.SECRET.NAC.DE SEG.PUB.
# 1                 26304       202056314       AERO AGRICOLA ROSARIENSE LTDA
# 2                 25763       202041291       KAIO GENARIO FERREIRA DE MELO
# 3                 26123       202060427      MARCIO ROBERTO SALES DE ARAUJO
# 4                  5390           /2003                                None
#
#   Classificacao_da_Ocorrencia Data_da_Ocorrencia Hora_da_Ocorrencia  \
# 0                    Acidente         2020-10-08              16:00
# 1                    Acidente         2020-12-09           21:30:00
# 2                    Acidente         2020-10-15              11:00
# 3                    Acidente         2020-11-19              15:00
# 4                    Acidente         2003-12-09               None
#
#                 Municipio             UF        Regiao  \
# 0                 CORUMBÁ             MS  Centro-Oeste
# 1  SANT'ANA DO LIVRAMENTO             RS           Sul
# 2               RIO CLARO             RJ       Sudeste
# 3         IPIXUNA DO PARÁ             PA         Norte
# 4                    None  Indeterminado          None
#
#                      Descricao_do_Tipo                      ICAO  Latitude  \
# 0  FALHA OU MAU FUNCIONAMENTO DO MOTOR         Fora de Aeródromo  -17,4417
# 1                          COMBUSTÍVEL         Fora de Aeródromo  -30,6056
# 2             PERDA DE CONTROLE EM VOO         Fora de Aeródromo  -22,7031
# 3                               OUTROS  Aeródromo não cadastrado  -2,52357
# 4                                 None                      None      None
#
#   Longitude Tipo_de_Aerodromo  \
# 0  -56,8269                 -
# 1  -55,0564                 -
# 2  -43,9947                 -
# 3  -47,5181              None
# 4      None              None
#
#                                            Historico Matricula  \
# 0  A aeronave decolou do Aeroporto Internacional ...     PRMJZ
# 1  A aeronave decolou da pista pouso eventual da ...     PRREN
# 2  A aeronave decolou de local desconhecido para ...     PRESK
# 3  A AERONAVE DECOLOU DE UMA PISTA DESCONHECIDA C...     PTOQB
# 4                                               None     N32TJ
#
#   Categoria_da_Aeronave                            Operador  \
# 0                   ADF  MINIST.JUST.SECRET.NAC.DE SEG.PUB.
# 1                   S11       AERO AGRICOLA ROSARIENSE LTDA
# 2                   TPP       KAIO GENARIO FERREIRA DE MELO
# 3                   TPP      MARCIO ROBERTO SALES DE ARAUJO
# 4           ESTRANGEIRA                                None
#
#   Tipo_de_Ocorrencia    Fase_da_Operacao           Operacao Danos_a_Aeronave  \
# 0             SCF-PP            Cruzeiro   Operação Pública      Substancial
# 1               FUEL  Voo a baixa altura  Operação Agrícola      Substancial
# 2              LOC-I            Cruzeiro        Voo Privado      Substancial
# 3               OTHR               Pouso        Voo Privado      Substancial
# 4               None                None        Voo Privado             None
#
#   Aerodromo_de_Destino Aerodromo_de_Origem  Lesoes_Fatais_Tripulantes  \
# 0                 SJQI                SBCR                        NaN
# 1                 None                None                        NaN
# 2                 None                None                        1.0
# 3                 None                None                        NaN
# 4                                                                 1.0
#
#    Lesoes_Fatais_Passageiros  Lesoes_Fatais_Terceiros  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        1.0                      NaN
# 3                        NaN                      NaN
# 4                        1.0                      0.0
#
#    Lesoes_Graves_Tripulantes  Lesoes_Graves_Passageiros  \
# 0                        2.0                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        0.0                        1.0
#
#    Lesoes_Graves_Terceiros  Lesoes_Leves_Tripulantes  \
# 0                      NaN                       1.0
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       1.0
# 4                      0.0                       0.0
#
#    Lesoes_Leves_Passageiros  Lesoes_Leves_Terceiros  Ilesos_Tripulantes  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 1.0
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       0.0                     0.0                 0.0
#
#    Ilesos_Passageiros  Lesoes_Desconhecidas_Tripulantes  \
# 0                 NaN                               NaN
# 1                 NaN                               NaN
# 2                 NaN                               NaN
# 3                 1.0                               NaN
# 4                 0.0                               0.0
#
#    Lesoes_Desconhecidas_Passageiros  Lesoes_Desconhecidas_Terceiros  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               0.0                             0.0
#
#       Modelo   CLS Tipo_ICAO     PMD  Numero_de_Assentos   Nome_do_Fabricante  \
# 0  AS 350 B2   H1T      AS50  2250.0                 6.0    EUROCOPTER FRANCE
# 1      A188B   L1P      C188  1905.0                 1.0      CESSNA AIRCRAFT
# 2        R44   H1P       R44  1088.0                 4.0  ROBINSON HELICOPTER
# 3       58TC   L2P      BE58  2767.0                 6.0       BEECH AIRCRAFT
# 4       None  None      None     NaN                 NaN                 None
#
#          PSSO
# 0  verdadeiro
# 1  verdadeiro
# 2  verdadeiro
# 3       falso
# 4  verdadeiro

# %% [markdown]
# #### 2°: Tratar os dados. Levar em considaração apenas as colunas: ["Numero da ocorrencia", "Classificacao da ocorrencia", "Data da ocorrencia", "Municipio", "UF", "Regiao"]

# %%
df.columns
# Out:
# Index(['Numero_da_Ocorrencia', 'Numero_da_Ficha', 'Operador_Padronizado',
#        'Classificacao_da_Ocorrencia', 'Data_da_Ocorrencia',
#        'Hora_da_Ocorrencia', 'Municipio', 'UF', 'Regiao', 'Descricao_do_Tipo',
#        'ICAO', 'Latitude', 'Longitude', 'Tipo_de_Aerodromo', 'Historico',
#        'Matricula', 'Categoria_da_Aeronave', 'Operador', 'Tipo_de_Ocorrencia',
#        'Fase_da_Operacao', 'Operacao', 'Danos_a_Aeronave',
#        'Aerodromo_de_Destino', 'Aerodromo_de_Origem',
#        'Lesoes_Fatais_Tripulantes', 'Lesoes_Fatais_Passageiros',
#        'Lesoes_Fatais_Terceiros', 'Lesoes_Graves_Tripulantes',
#        'Lesoes_Graves_Passageiros', 'Lesoes_Graves_Terceiros',
#        'Lesoes_Leves_Tripulantes', 'Lesoes_Leves_Passageiros',
#        'Lesoes_Leves_Terceiros', 'Ilesos_Tripulantes', 'Ilesos_Passageiros',
#        'Lesoes_Desconhecidas_Tripulantes', 'Lesoes_Desconhecidas_Passageiros',
#        'Lesoes_Desconhecidas_Terceiros', 'Modelo', 'CLS', 'Tipo_ICAO', 'PMD',
#        'Numero_de_Assentos', 'Nome_do_Fabricante', 'PSSO'],
#       dtype='object')

# %%
colunas = ["Numero_da_Ocorrencia", "Classificacao_da_Ocorrencia", "Data_da_Ocorrencia", "Municipio", "UF", "Regiao", "Nome_do_Fabricante"]
df = df[colunas] # Aqui eu tô pegando o meu dataframe e deixando somente com as colunas da variável colunas

# %%
df.head(3)
# Out:
#    Numero_da_Ocorrencia Classificacao_da_Ocorrencia Data_da_Ocorrencia  \
# 0                 25626                    Acidente         2020-10-08
# 1                 26304                    Acidente         2020-12-09
# 2                 25763                    Acidente         2020-10-15
#
#                 Municipio  UF        Regiao   Nome_do_Fabricante
# 0                 CORUMBÁ  MS  Centro-Oeste    EUROCOPTER FRANCE
# 1  SANT'ANA DO LIVRAMENTO  RS           Sul      CESSNA AIRCRAFT
# 2               RIO CLARO  RJ       Sudeste  ROBINSON HELICOPTER

# %% [markdown]
# #### 3°: Tirando o acento dos nomes das colunas

# %%
# df.rename(columns={'Classificacao_da_Ocorrência': 'Classificacao_da_Ocorrencia'}, inplace=True)

# %%
df.head(3)
# Out:
#    Numero_da_Ocorrencia Classificacao_da_Ocorrencia Data_da_Ocorrencia  \
# 0                 25626                    Acidente         2020-10-08
# 1                 26304                    Acidente         2020-12-09
# 2                 25763                    Acidente         2020-10-15
#
#                 Municipio  UF        Regiao   Nome_do_Fabricante
# 0                 CORUMBÁ  MS  Centro-Oeste    EUROCOPTER FRANCE
# 1  SANT'ANA DO LIVRAMENTO  RS           Sul      CESSNA AIRCRAFT
# 2               RIO CLARO  RJ       Sudeste  ROBINSON HELICOPTER

# %% [markdown]
# #### 4°: Criando banco de dados e tabela "**Foi feito pela interface do postgre**"

# %% [markdown]
# #### 5°: Configurando a conexão com o Postgre
# #### 6°: Enviar dados para o Postgre

# %% [markdown]
# #### 7°: Criar um DELETE da tabela para não ver histórico, mantendo em banco sempre os dados mais recentes

# %%
import psycopg2
dbname   = 'python'
user     = 'postgres'
password = 'senha123'
host     = 'localhost'
port     = '5432'

# 5°: Conexão com o postgre
conexao = psycopg2.connect(dbname=dbname,
                        user=user,
                        password=password,
                        host=host,
                        port=port)

cursor = conexao.cursor()

# 7°: Deletando a base de dados
cursor.execute("DELETE FROM Anc")


# 6°: Enviar dados para o Postgre
# Carga de dados
for indice, coluna_df in df.iterrows():
    cursor.execute("""
                    INSERT INTO Anc (
                    Numero_da_Ocorrencia,
                    Classificacao_da_ocorrencia,
                    Data_da_ocorrencia,
                    Municipio,
                    UF,
                    Regiao,
                    Nome_do_fabricante
                ) VALUES (%s, %s, %s, %s, %s, %s, %s)

                """, (
                        coluna_df["Numero_da_Ocorrencia"],
                        coluna_df["Classificacao_da_Ocorrencia"],
                        coluna_df["Data_da_Ocorrencia"],
                        coluna_df["Municipio"],
                        coluna_df["UF"],
                        coluna_df["Regiao"],
                        coluna_df["Nome_do_Fabricante"]

                     )
                   
                   
                   )
conexao.commit()
cursor.close()
conexao.close()
