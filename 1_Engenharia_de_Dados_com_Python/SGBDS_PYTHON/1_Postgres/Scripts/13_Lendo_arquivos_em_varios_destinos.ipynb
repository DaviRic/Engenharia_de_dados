# %%
import pandas as pd

# %% [markdown]
# #### Lendo de arquivo json

# %%
pasta_origem_json = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Destino\Anac_json.json"
df_json = pd.read_json(pasta_origem_json, orient='index')
df_json.head(5)
# Out:
#       id  dt_ocorrencia             uf        regiao  \
# 0  25626  1602115200000             MS  Centro-Oeste
# 1  26304  1607472000000             RS           Sul
# 2  25763  1602720000000             RJ       Sudeste
# 3  26123  1605744000000             PA         Norte
# 4   5390  1070928000000  Indeterminado          None
#
#   classificacao_da_ocorrencia
# 0                    Acidente
# 1                    Acidente
# 2                    Acidente
# 3                    Acidente
# 4                    Acidente

# %% [markdown]
# #### Lendo de arquivo excel

# %%
pasta_origem_excel = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Destino\Anac_excel.xlsx"
df_excel = pd.read_excel(pasta_origem_excel)
df_excel.head(5)

# sheet_name => carrega uma guia específica do arquivo csv. É só passar o nome da guia entre áspas
# Out:
#       id dt_ocorrencia             uf        regiao  \
# 0  25626    2020-10-08             MS  Centro-Oeste
# 1  26304    2020-12-09             RS           Sul
# 2  25763    2020-10-15             RJ       Sudeste
# 3  26123    2020-11-19             PA         Norte
# 4   5390    2003-12-09  Indeterminado           NaN
#
#   classificacao_da_ocorrencia
# 0                    Acidente
# 1                    Acidente
# 2                    Acidente
# 3                    Acidente
# 4                    Acidente

# %% [markdown]
# #### Lendo arquivo csv

# %%
pasta_origem_csv = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Destino\Anac_csv.csv"
df_csv = pd.read_csv(pasta_origem_csv, sep=',')
df_csv.head()
# Out:
#    Unnamed: 0     id dt_ocorrencia             uf        regiao  \
# 0           0  25626    2020-10-08             MS  Centro-Oeste
# 1           1  26304    2020-12-09             RS           Sul
# 2           2  25763    2020-10-15             RJ       Sudeste
# 3           3  26123    2020-11-19             PA         Norte
# 4           4   5390    2003-12-09  Indeterminado           NaN
#
#   classificacao_da_ocorrencia
# 0                    Acidente
# 1                    Acidente
# 2                    Acidente
# 3                    Acidente
# 4                    Acidente

# %% [markdown]
# #### Lendo arquivo parquet

# %%
pasta_origem_parquet = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Destino\Anac_parquet.parquet"
df_parquet = pd.read_parquet(pasta_origem_parquet)
df_parquet.head()
# Out:
#       id dt_ocorrencia             uf        regiao  \
# 0  25626    2020-10-08             MS  Centro-Oeste
# 1  26304    2020-12-09             RS           Sul
# 2  25763    2020-10-15             RJ       Sudeste
# 3  26123    2020-11-19             PA         Norte
# 4   5390    2003-12-09  Indeterminado          None
#
#   classificacao_da_ocorrencia
# 0                    Acidente
# 1                    Acidente
# 2                    Acidente
# 3                    Acidente
# 4                    Acidente

# %% [markdown]
# #### Lendo arquivo parquet particionado

# %%
pasta_origem_parquet_particionado = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Destino\Anac_particionado.parquet"
df_particionado = pd.read_parquet(pasta_origem_parquet_particionado, engine='fastparquet')
df_particionado.head()
# Out:
#       id        dt_ocorrencia  uf classificacao_da_ocorrencia        regiao
# 0  25626  1602115200000000000  MS                    Acidente  Centro-Oeste
# 1  26423  1608249600000000000  GO                    Acidente  Centro-Oeste
# 2  25322  1600214400000000000  GO                    Acidente  Centro-Oeste
# 3  25925  1583020800000000000  MT             Incidente Grave  Centro-Oeste
# 4  25426  1601337600000000000  MT                    Acidente  Centro-Oeste

# %% [markdown]
# #### Lendo arquivo parquet particionado (regiões)
