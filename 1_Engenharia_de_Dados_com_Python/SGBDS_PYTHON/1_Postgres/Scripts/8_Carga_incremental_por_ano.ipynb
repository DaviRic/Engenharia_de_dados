# %%
import pandas as pd
pd.set_option('display.max_columns', None)
caminho_do_arquivo = r"C:\Users\Cliente\Desktop\Engenharia_de_dados_com_Python\SGBDS_PYTHON\Postgree\V_OCORRENCIA_AMPLA.json"
df = pd.read_json(caminho_do_arquivo, encoding='utf-8')

colunas = ["Numero_da_Ocorrencia", "Classificacao_da_Ocorrencia", "Data_da_Ocorrencia", "Municipio", "UF", "Regiao", "Nome_do_Fabricante", "Modelo"]
df = df[colunas]
df.head(5)
# Out:
#    Numero_da_Ocorrencia Classificacao_da_Ocorrencia Data_da_Ocorrencia  \
# 0                 25626                    Acidente         2020-10-08
# 1                 26304                    Acidente         2020-12-09
# 2                 25763                    Acidente         2020-10-15
# 3                 26123                    Acidente         2020-11-19
# 4                  5390                    Acidente         2003-12-09
#
#                 Municipio             UF        Regiao   Nome_do_Fabricante  \
# 0                 CORUMBÁ             MS  Centro-Oeste    EUROCOPTER FRANCE
# 1  SANT'ANA DO LIVRAMENTO             RS           Sul      CESSNA AIRCRAFT
# 2               RIO CLARO             RJ       Sudeste  ROBINSON HELICOPTER
# 3         IPIXUNA DO PARÁ             PA         Norte       BEECH AIRCRAFT
# 4                    None  Indeterminado          None                 None
#
#       Modelo
# 0  AS 350 B2
# 1      A188B
# 2        R44
# 3       58TC
# 4       None

# %%
df.dtypes
# Out:
# Numero_da_Ocorrencia                    int64
# Classificacao_da_Ocorrencia            object
# Data_da_Ocorrencia             datetime64[ns]
# Municipio                              object
# UF                                     object
# Regiao                                 object
# Nome_do_Fabricante                     object
# Modelo                                 object
# dtype: object

# %%
df["Data_da_Ocorrencia"] = pd.to_datetime(df["Data_da_Ocorrencia"])

# %%
from datetime import datetime

ano_atual = datetime.now().year
# Out:
# 2024

# %%
df = df[df["Data_da_Ocorrencia"].dt.year == ano_atual]
df.head(10)
# Out:
#       Numero_da_Ocorrencia Classificacao_da_Ocorrencia Data_da_Ocorrencia  \
# 4026                 41729                    Acidente         2024-01-06
# 4035                 42584                    Acidente         2024-02-09
# 4039                 42074                    Acidente         2024-01-21
# 4048                 42895             Incidente Grave         2024-02-12
# 4049                 42986                    Acidente         2024-03-02
# 4055                 42193                    Acidente         2024-02-01
# 4056                 42194             Incidente Grave         2024-01-31
# 4057                 42194             Incidente Grave         2024-01-31
# 4058                 42266             Incidente Grave         2024-01-25
# 4062                 44366             Incidente Grave         2024-03-12
#
#                              Municipio  UF        Regiao  \
# 4026                          RIO SONO  TO         Norte
# 4035                            VIAMÃO  RS           Sul
# 4039                           MUCAJAÍ  RR         Norte
# 4048                  SÃO PEDRO DO SUL  RS           Sul
# 4049                         Barreiras  BA      Nordeste
# 4055  VILA BELA DA SANTÍSSIMA TRINDADE  MT  Centro-Oeste
# 4056                         BARREIRAS  BA      Nordeste
# 4057                         BARREIRAS  BA      Nordeste
# 4058                       Urberlândia  MG       Sudeste
# 4062                     São Desidério  BA      Nordeste
#
#                             Nome_do_Fabricante     Modelo
# 4026                           CESSNA AIRCRAFT       210L
# 4035                           CESSNA AIRCRAFT      T188C
# 4039                           CESSNA AIRCRAFT      U206G
# 4048                                     NEIVA    EMB-201
# 4049                MARCIO DE CASTRO VALADARES      RV-10
# 4055                            PIPER AIRCRAFT  PA-36-300
# 4056                           THRUSH AIRCRAFT    S2R-510
# 4057                           THRUSH AIRCRAFT    S2R-510
# 4058  JOSE GUILHERME FRANCA MENDES DE CARVALHO      RV-10
# 4062                           THRUSH AIRCRAFT    S2R-H80

# %%
from sqlalchemy import create_engine, Integer, String, Date, VARCHAR, text

dbname   = 'python'
user     = 'postgres'
password = 'senha123'
host     = 'localhost'
port     = '5432'

conexao_str = f'postgresql://{user}:{password}@{host}:{port}/{dbname}'

engine = create_engine(conexao_str)
nome_tabela = 'anac_sqlalchemy'

# Deletar registros com base no ano atual
cursor = engine.connect()
delete = text(f'DELETE FROM {nome_tabela} WHERE EXTRACT (YEAR FROM "Data_da_Ocorrencia") = {ano_atual}')
cursor.execute(delete)
cursor.commit

df.to_sql(nome_tabela, engine, index=False, if_exists='append',
          dtype={'Numero_da_Ocorrencia' : Integer,
              'Classificacao_da_Ocorrencia' : VARCHAR(50),
              'Data_da_Ocorrencia' : Date
            })

engine.dispose()
cursor.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      14 # Deletar registros com base no ano atual
#      15 cursor = engine.connect()
# ---> 16 delete = text(f'DELETE FROM {nome_tabela} WHERE EXTRACT (YEAR FROM "Data_da_Ocorrencia") = {ano_atual}')
#      17 cursor.execute(delete)
#      18 cursor.commit
#
# NameError: name 'ano_atual' is not defined
